# %%
#data loading

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df=pd.read_csv('Admission_Predict_Ver1.1.csv')

# %%
#data overview

# %%
df.tail()
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 495         496        332          108                  5  4.5   4.0  9.02
# 496         497        337          117                  5  5.0   5.0  9.87
# 497         498        330          120                  5  4.5   5.0  9.56
# 498         499        312          103                  4  4.0   5.0  8.43
# 499         500        327          113                  4  4.5   4.5  9.04
#
#      Research  Chance of Admit
# 495         1              0.87
# 496         1              0.96
# 497         1              0.93
# 498         0              0.73
# 499         0              0.84

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         500 non-null    int64
#  1   GRE Score          500 non-null    int64
#  2   TOEFL Score        500 non-null    int64
#  3   University Rating  500 non-null    int64
#  4   SOP                500 non-null    float64
#  5   LOR                500 non-null    float64
#  6   CGPA               500 non-null    float64
#  7   Research           500 non-null    int64
#  8   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 35.3 KB

# %%
df.shape
# Out:
# (500, 9)

# %%
df.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  500.000000  500.000000   500.000000         500.000000  500.000000
# mean   250.500000  316.472000   107.192000           3.114000    3.374000
# std    144.481833   11.295148     6.081868           1.143512    0.991004
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    125.750000  308.000000   103.000000           2.000000    2.500000
# 50%    250.500000  317.000000   107.000000           3.000000    3.500000
# 75%    375.250000  325.000000   112.000000           4.000000    4.000000
# max    500.000000  340.000000   120.000000           5.000000    5.000000
#
#             LOR         CGPA    Research  Chance of Admit
# count  500.00000  500.000000  500.000000         500.00000
# mean     3.48400    8.576440    0.560000           0.72174
# std      0.92545    0.604813    0.496884           0.14114
# min      1.00000    6.800000    0.000000           0.34000
# ...

# %%
df.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=500, step=1)

# %%
df.dtypes
# Out:
# Serial No.             int64
# GRE Score              int64
# TOEFL Score            int64
# University Rating      int64
# SOP                  float64
# LOR                  float64
# CGPA                 float64
# Research               int64
# Chance of Admit      float64
# dtype: object

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 495         496        332          108                  5  4.5   4.0  9.02
# 496         497        337          117                  5  5.0   5.0  9.87
# 497         498        330          120                  5  4.5   5.0  9.56
# 498         499        312          103                  4  4.0   5.0  8.43
# 499         500        327          113                  4  4.5   4.5  9.04
#
# ...

# %%
df.describe(include="all")
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  500.000000  500.000000   500.000000         500.000000  500.000000
# mean   250.500000  316.472000   107.192000           3.114000    3.374000
# std    144.481833   11.295148     6.081868           1.143512    0.991004
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    125.750000  308.000000   103.000000           2.000000    2.500000
# 50%    250.500000  317.000000   107.000000           3.000000    3.500000
# 75%    375.250000  325.000000   112.000000           4.000000    4.000000
# max    500.000000  340.000000   120.000000           5.000000    5.000000
#
#             LOR         CGPA    Research  Chance of Admit
# count  500.00000  500.000000  500.000000         500.00000
# mean     3.48400    8.576440    0.560000           0.72174
# std      0.92545    0.604813    0.496884           0.14114
# min      1.00000    6.800000    0.000000           0.34000
# ...

# %%
#checking missing  values

# %%
df.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Serial No., GRE Score, TOEFL Score, University Rating, SOP, LOR , CGPA, Research, Chance of Admit ]
# Index: []

# %%
df.dropna()
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 495         496        332          108                  5  4.5   4.0  9.02
# 496         497        337          117                  5  5.0   5.0  9.87
# 497         498        330          120                  5  4.5   5.0  9.56
# 498         499        312          103                  4  4.0   5.0  8.43
# 499         500        327          113                  4  4.5   4.5  9.04
#
#      Research  Chance of Admit
# ...

# %%
df.fillna('values')
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 495         496        332          108                  5  4.5   4.0  9.02
# 496         497        337          117                  5  5.0   5.0  9.87
# 497         498        330          120                  5  4.5   5.0  9.56
# 498         499        312          103                  4  4.0   5.0  8.43
# 499         500        327          113                  4  4.5   4.5  9.04
#
#      Research  Chance of Admit
# ...

# %%
df.fillna(df.median())
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 495         496        332          108                  5  4.5   4.0  9.02
# 496         497        337          117                  5  5.0   5.0  9.87
# 497         498        330          120                  5  4.5   5.0  9.56
# 498         499        312          103                  4  4.0   5.0  8.43
# 499         500        327          113                  4  4.5   4.5  9.04
#
#      Research  Chance of Admit
# ...

# %%
df.interpolate()
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 495         496        332          108                  5  4.5   4.0  9.02
# 496         497        337          117                  5  5.0   5.0  9.87
# 497         498        330          120                  5  4.5   5.0  9.56
# 498         499        312          103                  4  4.0   5.0  8.43
# 499         500        327          113                  4  4.5   4.5  9.04
#
#      Research  Chance of Admit
# ...

# %%
#checking duplicates

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Length: 500, dtype: bool

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Serial No., GRE Score, TOEFL Score, University Rating, SOP, LOR , CGPA, Research, Chance of Admit ]
# Index: []

# %%
df.drop_duplicates()
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 495         496        332          108                  5  4.5   4.0  9.02
# 496         497        337          117                  5  5.0   5.0  9.87
# 497         498        330          120                  5  4.5   5.0  9.56
# 498         499        312          103                  4  4.0   5.0  8.43
# 499         500        327          113                  4  4.5   4.5  9.04
#
#      Research  Chance of Admit
# ...

# %%
#summary statistics

# %%
df.mean()
# Out:
# Serial No.           250.50000
# GRE Score            316.47200
# TOEFL Score          107.19200
# University Rating      3.11400
# SOP                    3.37400
# LOR                    3.48400
# CGPA                   8.57644
# Research               0.56000
# Chance of Admit        0.72174
# dtype: float64

# %%
df.median()
# Out:
# Serial No.           250.50
# GRE Score            317.00
# TOEFL Score          107.00
# University Rating      3.00
# SOP                    3.50
# LOR                    3.50
# CGPA                   8.56
# Research               1.00
# Chance of Admit        0.72
# dtype: float64

# %%
df.mode()
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1      312.0        110.0                3.0  4.0   3.0  8.00
# 1             2        NaN          NaN                NaN  NaN   NaN  8.76
# 2             3        NaN          NaN                NaN  NaN   NaN   NaN
# 3             4        NaN          NaN                NaN  NaN   NaN   NaN
# 4             5        NaN          NaN                NaN  NaN   NaN   NaN
# ..          ...        ...          ...                ...  ...   ...   ...
# 495         496        NaN          NaN                NaN  NaN   NaN   NaN
# 496         497        NaN          NaN                NaN  NaN   NaN   NaN
# 497         498        NaN          NaN                NaN  NaN   NaN   NaN
# 498         499        NaN          NaN                NaN  NaN   NaN   NaN
# 499         500        NaN          NaN                NaN  NaN   NaN   NaN
#
#      Research  Chance of Admit
# ...

# %%
df.std()
# Out:
# Serial No.           144.481833
# GRE Score             11.295148
# TOEFL Score            6.081868
# University Rating      1.143512
# SOP                    0.991004
# LOR                    0.925450
# CGPA                   0.604813
# Research               0.496884
# Chance of Admit        0.141140
# dtype: float64

# %%
df.var()
# Out:
# Serial No.           20875.000000
# GRE Score              127.580377
# TOEFL Score             36.989114
# University Rating        1.307619
# SOP                      0.982088
# LOR                      0.856457
# CGPA                     0.365799
# Research                 0.246894
# Chance of Admit          0.019921
# dtype: float64

# %%
df.min()
# Out:
# Serial No.             1.00
# GRE Score            290.00
# TOEFL Score           92.00
# University Rating      1.00
# SOP                    1.00
# LOR                    1.00
# CGPA                   6.80
# Research               0.00
# Chance of Admit        0.34
# dtype: float64

# %%
df.max()
# Out:
# Serial No.           500.00
# GRE Score            340.00
# TOEFL Score          120.00
# University Rating      5.00
# SOP                    5.00
# LOR                    5.00
# CGPA                   9.92
# Research               1.00
# Chance of Admit        0.97
# dtype: float64

# %%
df.count()
# Out:
# Serial No.           500
# GRE Score            500
# TOEFL Score          500
# University Rating    500
# SOP                  500
# LOR                  500
# CGPA                 500
# Research             500
# Chance of Admit      500
# dtype: int64

# %%
df.nunique()
# Out:
# Serial No.           500
# GRE Score             49
# TOEFL Score           29
# University Rating      5
# SOP                    9
# LOR                    9
# CGPA                 184
# Research               2
# Chance of Admit       61
# dtype: int64

# %%
#values counts and distributions

# %%
df.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
df["GRE Score"].value_counts()
# Out:
# GRE Score
# 312    24
# 324    23
# 316    18
# 321    17
# 322    17
# 327    17
# 311    16
# 320    16
# 314    16
# 317    15
# 325    15
# 315    13
# 308    13
# 323    13
# 326    12
# 319    12
# 313    12
# 304    12
# 300    12
# 318    12
# 305    11
# 301    11
# 310    11
# 307    10
# 329    10
# 299    10
# 298    10
# 331     9
# 340     9
# 328     9
# 309     9
# 334     8
# 332     8
# 330     8
# 306     7
# 302     7
# 297     6
# 296     5
# 295     5
# 336     5
# 303     5
# 338     4
# 335     4
# 333     4
# 339     3
# 337     2
# 290     2
# 294     2
# 293     1
# Name: count, dtype: int64

# %%
df["GRE Score"].value_counts(normalize=True)
# Out:
# GRE Score
# 312    0.048
# 324    0.046
# 316    0.036
# 321    0.034
# 322    0.034
# 327    0.034
# 311    0.032
# 320    0.032
# 314    0.032
# 317    0.030
# 325    0.030
# 315    0.026
# 308    0.026
# 323    0.026
# 326    0.024
# 319    0.024
# 313    0.024
# 304    0.024
# 300    0.024
# 318    0.024
# 305    0.022
# 301    0.022
# 310    0.022
# 307    0.020
# 329    0.020
# 299    0.020
# 298    0.020
# 331    0.018
# 340    0.018
# 328    0.018
# 309    0.018
# 334    0.016
# 332    0.016
# 330    0.016
# 306    0.014
# 302    0.014
# 297    0.012
# 296    0.010
# 295    0.010
# 336    0.010
# 303    0.010
# 338    0.008
# 335    0.008
# 333    0.008
# 339    0.006
# 337    0.004
# 290    0.004
# 294    0.004
# 293    0.002
# Name: proportion, dtype: float64

# %%
df["GRE Score"].unique()
# Out:
# array([337, 324, 316, 322, 314, 330, 321, 308, 302, 323, 325, 327, 328,
#        307, 311, 317, 319, 318, 303, 312, 334, 336, 340, 298, 295, 310,
#        300, 338, 331, 320, 299, 304, 313, 332, 326, 329, 339, 309, 315,
#        301, 296, 294, 306, 305, 290, 335, 333, 297, 293], dtype=int64)

# %%
df["GRE Score"].nunique()
# Out:
# 49

# %%
#correlation and coraniance

# %%
df.corr()
# Out:
#                    Serial No.  GRE Score  TOEFL Score  University Rating  \
# Serial No.           1.000000  -0.103839    -0.141696          -0.067641
# GRE Score           -0.103839   1.000000     0.827200           0.635376
# TOEFL Score         -0.141696   0.827200     1.000000           0.649799
# University Rating   -0.067641   0.635376     0.649799           1.000000
# SOP                 -0.137352   0.613498     0.644410           0.728024
# LOR                 -0.003694   0.524679     0.541563           0.608651
# CGPA                -0.074289   0.825878     0.810574           0.705254
# Research            -0.005332   0.563398     0.467012           0.427047
# Chance of Admit      0.008505   0.810351     0.792228           0.690132
#
#                         SOP      LOR       CGPA  Research  Chance of Admit
# Serial No.        -0.137352 -0.003694 -0.074289 -0.005332          0.008505
# GRE Score          0.613498  0.524679  0.825878  0.563398          0.810351
# ...

# %%
df.corr(method="kendall")
# Out:
#                    Serial No.  GRE Score  TOEFL Score  University Rating  \
# Serial No.           1.000000  -0.068496    -0.098656          -0.040534
# GRE Score           -0.068496   1.000000     0.655920           0.514842
# TOEFL Score         -0.098656   0.655920     1.000000           0.520345
# University Rating   -0.040534   0.514842     0.520345           1.000000
# SOP                 -0.101583   0.475974     0.504574           0.624569
# LOR                  0.002344   0.386159     0.403507           0.497402
# CGPA                -0.053469   0.651313     0.635410           0.565745
# Research            -0.004358   0.478379     0.396523           0.394370
# Chance of Admit     -0.005993   0.647169     0.622481           0.570844
#
#                         SOP      LOR       CGPA  Research  Chance of Admit
# Serial No.        -0.101583  0.002344 -0.053469 -0.004358         -0.005993
# GRE Score          0.475974  0.386159  0.651313  0.478379          0.647169
# ...

# %%
df.corr(method="spearman")
# Out:
#                    Serial No.  GRE Score  TOEFL Score  University Rating  \
# Serial No.           1.000000  -0.099592    -0.142607          -0.055424
# GRE Score           -0.099592   1.000000     0.823853           0.643423
# TOEFL Score         -0.142607   0.823853     1.000000           0.645533
# University Rating   -0.055424   0.643423     0.645533           1.000000
# SOP                 -0.144249   0.620688     0.644715           0.729399
# LOR                  0.004220   0.514352     0.523434           0.602319
# CGPA                -0.075126   0.829251     0.809485           0.703333
# Research            -0.005332   0.578487     0.474540           0.435351
# Chance of Admit     -0.001733   0.822201     0.793634           0.703742
#
#                         SOP      LOR       CGPA  Research  Chance of Admit
# Serial No.        -0.144249  0.004220 -0.075126 -0.005332         -0.001733
# GRE Score          0.620688  0.514352  0.829251  0.578487          0.822201
# ...

# %%
df.corr()
# Out:
#                    Serial No.  GRE Score  TOEFL Score  University Rating  \
# Serial No.           1.000000  -0.103839    -0.141696          -0.067641
# GRE Score           -0.103839   1.000000     0.827200           0.635376
# TOEFL Score         -0.141696   0.827200     1.000000           0.649799
# University Rating   -0.067641   0.635376     0.649799           1.000000
# SOP                 -0.137352   0.613498     0.644410           0.728024
# LOR                 -0.003694   0.524679     0.541563           0.608651
# CGPA                -0.074289   0.825878     0.810574           0.705254
# Research            -0.005332   0.563398     0.467012           0.427047
# Chance of Admit      0.008505   0.810351     0.792228           0.690132
#
#                         SOP      LOR       CGPA  Research  Chance of Admit
# Serial No.        -0.137352 -0.003694 -0.074289 -0.005332          0.008505
# GRE Score          0.613498  0.524679  0.825878  0.563398          0.810351
# ...

# %%
#datavisualization(quick plots)

# %%
df.hist(figsize=(10,5))
plt.show()

# %%
df.boxplot(figsize =(10,5))
plt.show()

# %%
df["TOEFL Score"].plot(kind="hist")
plt.show()

# %%
df.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
df['University Rating'].plot(kind='box')
plt.show()

# %%
df['University Rating'].plot(kind='hist')
plt.show()

# %%
df['University Rating'].plot(kind='box')
plt.show()

# %%
df['Research'].plot(kind='box')
plt.show()

# %%
df['Research'].plot(kind='hist')
plt.show()
